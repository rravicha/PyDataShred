# %%
# !pip install -r requirements.txt
import sys
sys.path.append('/workspaces/PyDataShred')
from datashredpy.api.models import Client
from datashredpy.helper.data import Data
from datashredpy.helper.enums import FileType
# Out:
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python3 -m pip install --upgrade pip
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 5
#       3 sys.path.append('/workspaces/PyDataShred')
#       4 from datashredpy.api.models import Client
# ----> 5 from datashredpy.helper.data import Data
#       6 from datashredpy.helper.enums import FileType
#
# File /workspaces/PyDataShred/datashredpy/helper/data.py:5
#       3 from datashredpy.helper.enums import FileType, DbType
#       4 from typing import Optional
# ----> 5 import pandas as Pandas
#       7 from datashredpy.utilities.init_spark import SparkSessionOption
#       9 class Data:
#
# ModuleNotFoundError: No module named 'pandas'
