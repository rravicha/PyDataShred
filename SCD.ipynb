# %% [markdown]
# Testing SCD with two csv file

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: aenum==3.1.15 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from -r requirements.txt (line 1)) (3.1.15)
# Collecting annotated-types==0.7.0 (from -r requirements.txt (line 2))
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting anyio==4.4.0 (from -r requirements.txt (line 3))
#   Using cached anyio-4.4.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting archspec (from -r requirements.txt (line 4))
#   Using cached archspec-0.2.5-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: argon2-cffi==23.1.0 in /home/codespace/.local/lib/python3.12/site-packages (from -r requirements.txt (line 5)) (23.1.0)
# Requirement already satisfied: argon2-cffi-bindings==21.2.0 in /home/codespace/.local/lib/python3.12/site-packages (from -r requirements.txt (line 6)) (21.2.0)
# Requirement already satisfied: arrow==1.3.0 in /home/codespace/.local/lib/python3.12/site-packages (from -r requirements.txt (line 7)) (1.3.0)
# Collecting asn1crypto==1.5.1 (from -r requirements.txt (line 8))
#   Using cached asn1crypto-1.5.1-py2.py3-none-any.whl.metadata (13 kB)
# Collecting astroid==3.2.4 (from -r requirements.txt (line 9))
#   Using cached astroid-3.2.4-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: asttokens==3.0.0 in /home/codespace/.local/lib/python3.12/site-packages (from -r requirements.txt (line 10)) (3.0.0)
# Requirement already satisfied: async-lru==2.0.4 in /home/codespace/.local/lib/python3.12/site-packages (from -r requirements.txt (line 11)) (2.0.4)
# Requirement already satisfied: attrs==24.2.0 in /home/codespace/.local/lib/python3.12/site-packages (from -r requirements.txt (line 12)) (24.2.0)
# Collecting azure-functions==1.20.0 (from -r requirements.txt (line 13))
#   Using cached azure_functions-1.20.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: babel==2.16.0 in /home/codespace/.local/lib/python3.12/site-packages (from -r requirements.txt (line 14)) (2.16.0)
# Collecting backports.tarfile==1.2.0 (from -r requirements.txt (line 15))
#   Using cached backports.tarfile-1.2.0-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: beautifulsoup4==4.12.3 in /home/codespace/.local/lib/python3.12/site-packages (from -r requirements.txt (line 16)) (4.12.3)
# Requirement already satisfied: bleach==6.1.0 in /home/codespace/.local/lib/python3.12/site-packages (from -r requirements.txt (line 17)) (6.1.0)
# Collecting blinker==1.9.0 (from -r requirements.txt (line 18))
#   Using cached blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting boltons (from -r requirements.txt (line 19))
#   Using cached boltons-25.0.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting Brotli (from -r requirements.txt (line 20))
#   Using cached Brotli-1.1.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.5 kB)
# Collecting build==1.2.1 (from -r requirements.txt (line 21))
#   Using cached build-1.2.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: certifi==2024.8.30 in /home/codespace/.local/lib/python3.12/site-packages (from -r requirements.txt (line 22)) (2024.8.30)
# Collecting cffi==1.17.0 (from -r requirements.txt (line 23))
#   Using cached cffi-1.17.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: charset-normalizer==3.3.2 in /home/codespace/.local/lib/python3.12/site-packages (from -r requirements.txt (line 24)) (3.3.2)
# Collecting click==8.1.7 (from -r requirements.txt (line 25))
#   Using cached click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting cloudpickle==2.2.1 (from -r requirements.txt (line 26))
#   Using cached cloudpickle-2.2.1-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: colorama==0.4.6 in /home/codespace/.local/lib/python3.12/site-packages (from -r requirements.txt (line 27)) (0.4.6)
# Requirement already satisfied: comm==0.2.2 in /home/codespace/.local/lib/python3.12/site-packages (from -r requirements.txt (line 28)) (0.2.2)
# ERROR: Ignored the following yanked versions: 3.0.6, 3.5.0, 3.7.0, 3.17.0, 4.0.0, 4.0.1, 4.0.2, 4.0.3, 4.0.4, 4.0.5, 4.0.7, 4.0.8, 4.0.9, 4.1.2, 4.1.6, 4.2.6, 4.2.7, 4.3.13, 4.3.16
# ERROR: Could not find a version that satisfies the requirement conda (from versions: none)
#
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python3 -m pip install --upgrade pip
# ERROR: No matching distribution found for conda

# %%
# import sys
# sys.path.append('/workspaces/PyDataShred/')
# sys.path.append('/workspaces/PyDataShred/tests_data/HATCHBACK')

from datashredpy.helper.enums import FileType
from datashredpy.helper.data import Data
from datashredpy.helper.transform import ETL
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 6
#       1 # import sys
#       2 # sys.path.append('/workspaces/PyDataShred/')
#       3 # sys.path.append('/workspaces/PyDataShred/tests_data/HATCHBACK')
#       5 from datashredpy.helper.enums import FileType
# ----> 6 from datashredpy.helper.data import Data
#       7 from datashredpy.helper.transform import ETL
#
# File /workspaces/PyDataShred/datashredpy/helper/data.py:2
#       1 # from snowflake.snowpark import Session
# ----> 2 import requests
#       3 from typing import Optional, List, Dict
#       4 import pandas as Pandas
#
# File ~/.local/lib/python3.12/site-packages/requests/__init__.py:43
#       6 """
#       7 Requests HTTP Library
#       8 ~~~~~~~~~~~~~~~~~~~~~
#    (...)
#      38 :license: Apache 2.0, see LICENSE for more details.
#      39 """
#      41 import warnings
# ---> 43 import urllib3
#      45 from .exceptions import RequestsDependencyWarning
#      47 try:
#
# ModuleNotFoundError: No module named 'urllib3'

# %%
DF1 = '/workspaces/PyDataShred/tests_data/HATCHBACK/scd/supply_v1.csv'
DF2 = '/workspaces/PyDataShred/tests_data/HATCHBACK/scd/supply_v2.csv'
data1 = Data.read(DF1, file_type=FileType.CSV)
data1.show()
data2 = Data.read(DF2, file_type=FileType.CSV)
data2.show()
data3= ETL.apply_scd2(data1, data2, key_columns=['id'])
data3.show()
