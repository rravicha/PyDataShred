# %%
import sys
sys.path.append('/workspaces/PyDataShred')
from datashredpy.api.models import Client
from datashredpy.helper.data import Data
from datashredpy.helper.enums import FileType
# Out:
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python3 -m pip install --upgrade pip
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 5
#       3 sys.path.append('/workspaces/PyDataShred')
#       4 from datashredpy.api.models import Client
# ----> 5 from datashredpy.helper.data import Data
#       6 from datashredpy.helper.enums import FileType
#
# File /workspaces/PyDataShred/datashredpy/helper/data.py:5
#       3 from datashredpy.helper.enums import FileType, DbType
#       4 from typing import Optional
# ----> 5 import pandas as Pandas
#       7 from datashredpy.utilities.init_spark import SparkSessionOption
#       9 class Data:
#
# ModuleNotFoundError: No module named 'pandas'

# %%
# !pip install dist/pydatashred-1.0-py2.py3-none-any.whl
# Out:
# Processing ./dist/pydatashred-1.0-py2.py3-none-any.whl
# Requirement already satisfied: aenum==3.1.15 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydatashred==1.0) (3.1.15)
# Collecting annotated-types==0.7.0 (from pydatashred==1.0)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting anyio==4.4.0 (from pydatashred==1.0)
#   Using cached anyio-4.4.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting asn1crypto==1.5.1 (from pydatashred==1.0)
#   Using cached asn1crypto-1.5.1-py2.py3-none-any.whl.metadata (13 kB)
# Collecting astroid==3.2.4 (from pydatashred==1.0)
#   Using cached astroid-3.2.4-py3-none-any.whl.metadata (4.5 kB)
# Collecting azure-functions==1.20.0 (from pydatashred==1.0)
#   Using cached azure_functions-1.20.0-py3-none-any.whl.metadata (6.9 kB)
# Collecting backports.tarfile==1.2.0 (from pydatashred==1.0)
#   Using cached backports.tarfile-1.2.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting build==1.2.1 (from pydatashred==1.0)
#   Using cached build-1.2.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: certifi==2024.8.30 in /home/codespace/.local/lib/python3.12/site-packages (from pydatashred==1.0) (2024.8.30)
# Collecting cffi==1.17.0 (from pydatashred==1.0)
#   Using cached cffi-1.17.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: charset-normalizer==3.3.2 in /home/codespace/.local/lib/python3.12/site-packages (from pydatashred==1.0) (3.3.2)
# Collecting click==8.1.7 (from pydatashred==1.0)
#   Using cached click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting cloudpickle==2.2.1 (from pydatashred==1.0)
#   Using cached cloudpickle-2.2.1-py3-none-any.whl.metadata (6.9 kB)
# Collecting cryptography==43.0.0 (from pydatashred==1.0)
#   Using cached cryptography-43.0.0-cp39-abi3-manylinux_2_28_x86_64.whl.metadata (5.4 kB)
# Collecting deltalake==0.19.1 (from pydatashred==1.0)
#   Using cached deltalake-0.19.1-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.0 kB)
# Collecting dill==0.3.8 (from pydatashred==1.0)
#   Using cached dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Collecting docutils==0.21.2 (from pydatashred==1.0)
#   Using cached docutils-0.21.2-py3-none-any.whl.metadata (2.8 kB)
# Collecting et-xmlfile==1.1.0 (from pydatashred==1.0)
#   Using cached et_xmlfile-1.1.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting exceptiongroup==1.2.2 (from pydatashred==1.0)
#   Using cached exceptiongroup-1.2.2-py3-none-any.whl.metadata (6.6 kB)
# Collecting fastapi==0.113.0 (from pydatashred==1.0)
#   Using cached fastapi-0.113.0-py3-none-any.whl.metadata (27 kB)
# Collecting filelock==3.15.4 (from pydatashred==1.0)
#   Using cached filelock-3.15.4-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: h11==0.14.0 in /home/codespace/.local/lib/python3.12/site-packages (from pydatashred==1.0) (0.14.0)
# Collecting idna==3.8 (from pydatashred==1.0)
#   Using cached idna-3.8-py3-none-any.whl.metadata (9.9 kB)
# Collecting importlib-metadata==8.4.0 (from pydatashred==1.0)
#   Using cached importlib_metadata-8.4.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting iniconfig==2.0.0 (from pydatashred==1.0)
#   Using cached iniconfig-2.0.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting isort==5.13.2 (from pydatashred==1.0)
#   Using cached isort-5.13.2-py3-none-any.whl.metadata (12 kB)
# Collecting jaraco.classes==3.4.0 (from pydatashred==1.0)
#   Using cached jaraco.classes-3.4.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting jaraco.context==6.0.1 (from pydatashred==1.0)
#   Using cached jaraco.context-6.0.1-py3-none-any.whl.metadata (4.1 kB)
# Collecting jaraco.functools==4.0.2 (from pydatashred==1.0)
#   Using cached jaraco.functools-4.0.2-py3-none-any.whl.metadata (2.8 kB)
# Collecting jeepney==0.8.0 (from pydatashred==1.0)
#   Using cached jeepney-0.8.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting keyring==25.3.0 (from pydatashred==1.0)
#   Using cached keyring-25.3.0-py3-none-any.whl.metadata (20 kB)
# Collecting lxml==5.3.0 (from pydatashred==1.0)
#   Using cached lxml-5.3.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (3.8 kB)
# Collecting markdown-it-py==3.0.0 (from pydatashred==1.0)
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Collecting mccabe==0.7.0 (from pydatashred==1.0)
#   Using cached mccabe-0.7.0-py2.py3-none-any.whl.metadata (5.0 kB)
# Collecting mdurl==0.1.2 (from pydatashred==1.0)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting more-itertools==10.4.0 (from pydatashred==1.0)
#   Using cached more_itertools-10.4.0-py3-none-any.whl.metadata (36 kB)
# Collecting nh3==0.2.18 (from pydatashred==1.0)
#   Using cached nh3-0.2.18-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.7 kB)
# Collecting numpy==2.1.0 (from pydatashred==1.0)
#   Using cached numpy-2.1.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
# Collecting openpyxl==3.1.5 (from pydatashred==1.0)
#   Using cached openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting packaging==24.1 (from pydatashred==1.0)
#   Using cached packaging-24.1-py3-none-any.whl.metadata (3.2 kB)
# Collecting pandas==2.2.2 (from pydatashred==1.0)
#   Using cached pandas-2.2.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (19 kB)
# Collecting pkginfo==1.10.0 (from pydatashred==1.0)
#   Using cached pkginfo-1.10.0-py3-none-any.whl.metadata (11 kB)
# Collecting platformdirs==4.2.2 (from pydatashred==1.0)
#   Using cached platformdirs-4.2.2-py3-none-any.whl.metadata (11 kB)
# Collecting pluggy==1.5.0 (from pydatashred==1.0)
#   Using cached pluggy-1.5.0-py3-none-any.whl.metadata (4.8 kB)
# Collecting py4j==0.10.9.7 (from pydatashred==1.0)
#   Using cached py4j-0.10.9.7-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting pyarrow==17.0.0 (from pydatashred==1.0)
#   Using cached pyarrow-17.0.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (3.3 kB)
# Requirement already satisfied: pycparser==2.22 in /home/codespace/.local/lib/python3.12/site-packages (from pydatashred==1.0) (2.22)
# Collecting pydantic==2.9.0 (from pydatashred==1.0)
#   Using cached pydantic-2.9.0-py3-none-any.whl.metadata (146 kB)
# Collecting pydantic-core==2.23.2 (from pydatashred==1.0)
#   Using cached pydantic_core-2.23.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: Pygments==2.18.0 in /home/codespace/.local/lib/python3.12/site-packages (from pydatashred==1.0) (2.18.0)
# Collecting PyJWT==2.9.0 (from pydatashred==1.0)
#   Using cached PyJWT-2.9.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting pylint==3.2.6 (from pydatashred==1.0)
#   Using cached pylint-3.2.6-py3-none-any.whl.metadata (12 kB)
# Collecting pyOpenSSL==24.2.1 (from pydatashred==1.0)
#   Downloading pyOpenSSL-24.2.1-py3-none-any.whl.metadata (13 kB)
# Collecting pyproject-hooks==1.1.0 (from pydatashred==1.0)
#   Using cached pyproject_hooks-1.1.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting pyspark==3.5.2 (from pydatashred==1.0)
#   Using cached pyspark-3.5.2-py2.py3-none-any.whl
# Collecting pytest==8.3.2 (from pydatashred==1.0)
#   Using cached pytest-8.3.2-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: python-dateutil==2.9.0.post0 in /home/codespace/.local/lib/python3.12/site-packages (from pydatashred==1.0) (2.9.0.post0)
# Collecting pytz==2024.1 (from pydatashred==1.0)
#   Using cached pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: PyYAML==6.0.2 in /home/codespace/.local/lib/python3.12/site-packages (from pydatashred==1.0) (6.0.2)
# Collecting readme-renderer==44.0 (from pydatashred==1.0)
#   Using cached readme_renderer-44.0-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: requests==2.32.3 in /home/codespace/.local/lib/python3.12/site-packages (from pydatashred==1.0) (2.32.3)
# Collecting requests-toolbelt==1.0.0 (from pydatashred==1.0)
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting rfc3986==2.0.0 (from pydatashred==1.0)
#   Using cached rfc3986-2.0.0-py2.py3-none-any.whl.metadata (6.6 kB)
# Collecting rich==13.8.0 (from pydatashred==1.0)
#   Using cached rich-13.8.0-py3-none-any.whl.metadata (18 kB)
# Collecting SecretStorage==3.3.3 (from pydatashred==1.0)
#   Using cached SecretStorage-3.3.3-py3-none-any.whl.metadata (4.0 kB)
# Collecting six==1.16.0 (from pydatashred==1.0)
#   Using cached six-1.16.0-py2.py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: sniffio==1.3.1 in /home/codespace/.local/lib/python3.12/site-packages (from pydatashred==1.0) (1.3.1)
# INFO: pip is looking at multiple versions of pydatashred to determine which version is compatible with other requirements. This could take a while.
# ERROR: Ignored the following versions that require a different python version: 0.10.0 Requires-Python ==3.8.*; 0.11.0 Requires-Python ==3.8.*; 0.12.0 Requires-Python ==3.8.*; 0.6.0 Requires-Python ==3.8.*; 0.7.0 Requires-Python ==3.8.*; 0.8.0 Requires-Python ==3.8.*; 0.9.0 Requires-Python ==3.8.*; 1.0.0 Requires-Python ==3.8.*; 1.1.0 Requires-Python ==3.8.*; 1.10.0 Requires-Python >=3.8, <3.12; 1.11.0 Requires-Python >=3.8, <3.12; 1.11.1 Requires-Python >=3.8, <3.12; 1.12.0 Requires-Python >=3.8, <3.12; 1.12.1 Requires-Python >=3.8, <3.12; 1.13.0 Requires-Python >=3.8, <3.12; 1.14.0 Requires-Python <3.12,>=3.8; 1.15.0 Requires-Python <3.12,>=3.8; 1.16.0 Requires-Python <3.12,>=3.8; 1.17.0 Requires-Python <3.12,>=3.8; 1.18.0 Requires-Python <3.12,>=3.8; 1.19.0 Requires-Python <3.12,>=3.8; 1.2.0 Requires-Python ==3.8.*; 1.20.0 Requires-Python <3.12,>=3.8; 1.21.0 Requires-Python <3.12,>=3.8; 1.21.1 Requires-Python <3.12,>=3.8; 1.21.2 Requires-Python >=3.7,<3.11; 1.21.3 Requires-Python >=3.7,<3.11; 1.21.4 Requires-Python >=3.7,<3.11; 1.21.5 Requires-Python >=3.7,<3.11; 1.21.6 Requires-Python >=3.7,<3.11; 1.22.0 Requires-Python <3.12,>=3.8; 1.22.1 Requires-Python <3.12,>=3.8; 1.23.0 Requires-Python <3.12,>=3.8; 1.24.0 Requires-Python <3.12,>=3.8; 1.25.0 Requires-Python <3.12,>=3.8; 1.26.0 Requires-Python <3.12,>=3.8; 1.3.0 Requires-Python ==3.8.*; 1.4.0 Requires-Python ==3.8.*; 1.5.0 Requires-Python >=3.8, <3.10; 1.5.1 Requires-Python >=3.8, <3.11; 1.6.0 Requires-Python >=3.8, <3.11; 1.6.1 Requires-Python >=3.8, <3.11; 1.7.0 Requires-Python >=3.8, <3.11; 1.8.0 Requires-Python >=3.8, <3.11; 1.9.0 Requires-Python >=3.8, <3.12; 1.9.5 Requires-Python >=2.7, !=3.0.*, !=3.1.*, !=3.2.*, !=3.3.*, <3.7
# ERROR: Could not find a version that satisfies the requirement snowflake-snowpark-python (from pydatashred) (from versions: none)
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python3 -m pip install --upgrade pip
# ERROR: No matching distribution found for snowflake-snowpark-python
# Bad pipe message: %s [b'iP\x9d\xc2\xc2%\xe7]\x8c]\xdf\x00Qo\xc0\xf6G`\x00\x01|\x00\x00\x00\x01\x00\x02\x00\x03\x00\x04\x00\x05\x00\x06\x00\x07\x00\x08\x00\t\x00\n\x00\x0b\x00\x0c\x00\r\x00\x0e\x00\x0f\x00\x10\x00\x11\x00\x12\x00\x13\x00\x14\x00\x15\x00\x16\x00\x17\x00\x18\x00\x19\x00\x1a\x00\x1b\x00/\x000\x001\x002\x003\x004\x005\x006\x007\x008\x009\x00:\x00;\x00<\x00=\x00>\x00?\x00@\x00A\x00B\x00C\x00D\x00E\x00F\x00g\x00h\x00i\x00j\x00k\x00l\x00m\x00\x84\x00\x85\x00\x86\x00\x87\x00\x88\x00\x89\x00\x96\x00\x97\x00\x98\x00\x99\x00\x9a\x00\x9b\x00\x9c']
# Bad pipe message: %s [b'f\xc39\t\xc4T\xaf+M\n\xce8\xc3\xf4\x18?;\x94\x00\x01|\x00\x00\x00\x01\x00\x02\x00\x03\x00\x04\x00\x05\x00\x06\x00\x07\x00\x08\x00\t\x00\n\x00\x0b\x00\x0c\x00\r\x00\x0e\x00\x0f\x00\x10\x00\x11\x00\x12\x00\x13\x00\x14\x00\x15\x00\x16\x00\x17\x00\x18\x00\x19\x00', b'\x1b\x00/\x000\x001\x002\x003\x004\x005\x006\x007\x008\x009\x00:']
# Bad pipe message: %s [b'Qh\x17\xce\xe5\xe5\xde', b'\x07\x84', b'\xcb\xc0\x00w\xdd\x00\x01|\x00\x00\x00\x01\x00\x02\x00\x03\x00\x04\x00\x05\x00\x06\x00\x07\x00\x08\x00\t\x00\n\x00\x0b\x00\x0c\x00\r\x00\x0e\x00\x0f\x00\x10\x00\x11\x00\x12\x00\x13\x00\x14\x00\x15\x00\x16\x00\x17\x00\x18\x00\x19\x00\x1a\x00\x1b\x00/\x000\x001\x002\x003\x004\x005\x006\x007\x008\x009\x00:\x00;\x00<\x00=\x00>\x00?\x00@\x00A\x00B\x00C\x00D\x00E\x00F\x00g\x00h\x00i\x00j\x00k\x00l\x00m', b"\xc0\t\xc0\n\xc0\x0b\xc0\x0c\xc0\r\xc0\x0e\xc0\x0f\xc0\x10\xc0\x11\xc0\x12\xc0\x13\xc0\x14\xc0\x15\xc0\x16\xc0\x17\xc0\x18\xc0\x19\xc0#\xc0$\xc0%\xc0&\xc0'\xc0(\xc0)\xc0*\xc0+\xc0,\xc0-\xc0.\xc0/\xc00\xc01\xc02\xc0r\xc0s\xc0t\xc0u\xc0v\xc0w\xc0x\xc0y\xc0z\xc0{\xc0|\xc0}\xc0~,\x00\n\x00\n\x00\x08\x00\x17\x00\x19\x00\x18\x00\x16\x00\x0b\x00\x04\x03\x00\x01\x02"]
# Bad pipe message: %s [b'\x0b1\x07~\xa3\x8b\x1e\xa0D\xe2\xb2\xb4P.:\xfc\xa2\xb6\x00\x01|\x00\x00\x00\x01\x00\x02\x00\x03']
# Bad pipe message: %s [b'\x90\x99\xda\xa4F_t\xa5\x0c\xf5\xc8\xfb\x97(e\x08C,\x00\x00']
# Bad pipe message: %s [b'A\x00B\x00C\x00D\x00E\x00F\x00\x84\x00\x85\x00\x86\x00\x87\x00\x88\x00\x89\x00\xba\x00\xbb\x00\xbc\x00\xbd\x00\xbe\x00\xbf\x00\xc0\x00\xc1\x00\xc2\x00\xc3\x00\xc4\x00\xc5']
# Bad pipe message: %s [b'\x01']
# Bad pipe message: %s [b'X\x86\xab:-`\xd7\xb1\xf9\x7fK\xd0b^\xd9\x0e\xff\x94\x00\x00\n\x13\x01\x13\x02\x13\x03\x13', b'\x05\x02\x00', b'']
# Bad pipe message: %s [b'\x8f\xcbT#\x02k\xbd\xcc\xac\x07\x82tq`\xc7}\xf7D\x00']
# Bad pipe message: %s [b'\x0c\xf3\x80q\xdd\x04fe\x11\n\xd9\xe1\xe9\x81\x0f;\xa9\xa9\x00\x00*\x00\x03\x00\x06\x00\x07\x00\x08\x00\t\x00\x0b\x00\x0c\x00\x0e\x00\x0f']
# Bad pipe message: %s [b'F\xa4\x1b!`\xb0\x8f\xed\x80]\xd1\x87V\xd3\xd4 \x9a\x81\x00\x00J\x00\x00\x00\x01\x00\x02\x00\x04\x00\x05\x00\n\x00\r\x00\x10\x00\x13\x00\x16\x00\x18\x00\x1b\x00/\x000\x001\x002\x003\x004\x005\x006\x007\x008\x009\x00:\x00;\x00<\x00=\x00>\x00?\x00@']
# Bad pipe message: %s [b"T\x1c\xa6\x95\xbe\x9a T,\x06\xfb\x16K\xf3\xeb\xef\xa7+ vdKk\x8c+\xe6\x88e;D\xba\x00<\xa3\n\xd1\xdeH\xf0\x887B'\xf5\xe6\x98D\xc0\xc6w_\x00\n\x13\x01\x13\x02\x13\x03\x13\x04\x13"]
# Bad pipe message: %s [b'\x00\x00\x9d\x00', b'\x03\x02\x03\x04\x00\n\x00\n\x00\x08\xaa\xaa\x00\x17\x00\x18\x00\x1d\x00\x00\x00\x0f\x00\r\x00\x00\nLTIN489792\x00\r\x00\x12\x00']
# Bad pipe message: %s [b'\x03\x08\x04\x04\x01\x05\x03\x08\x05\x05\x01\x08\x06\x06\x01']

# %%
from datashredpy.helper.models import *

# %%
meta_data = Domain(
    domain_id=1,
    domain_name='reference',
    app=App(
        app_id=1,
        app_name='oem',
        resources=Resources(
            source=Aws(
                url='console.aws.amazon.com',
                region='us-east-1',
                s3=S3(bucket=Bucket(name='datashred-client1',prefix='raw/reference/oem',file_name='employee.csv'))
                ),
            target=Aws(
                url='console.aws.amazon.com',
                region='us-west-2',
                rds=Rds(database='client1-reference', schema='oem', tablename='employee')
            )
        )
    )
)

client1 = Client(client_id=1, client_name='client1', domain=meta_data)
print(client1)
print(dir(client1.domain))
# form a json for class client
# Out:
# Client(client_id=1, client_name='client1', domain=Domain(domain_id=1, domain_name='reference', app=App(app_id=1, app_name='oem', resources=Resources(source=Aws(url='console.aws.amazon.com', region='us-east-1', s3=S3(bucket=Bucket(name='datashred-client1', prefix='raw/reference/oem', file_name='employee.csv')), rds=None), target=Aws(url='console.aws.amazon.com', region='us-west-2', s3=None, rds=Rds(database='client1-reference', schema='oem', tablename='employee'))))))
# ['__annotations__', '__class__', '__dataclass_fields__', '__dataclass_params__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__match_args__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'app', 'domain_id', 'domain_name']
