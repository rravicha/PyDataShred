# %%
import sys
sys.path.append('/workspaces/PyDataShred')

# %%
from datashredpy.helper.models import *

# %%
meta_data = Domain(
    domain_id=1,
    domain_name='employee',
    app=App(
        app_id=1,
        app_name='mechanic',
        resources=Resources(
            source=Aws(
                url='console.aws.amazon.com',
                region='us-east-1',
                s3=S3(bucket=Bucket(name='indigo',prefix='raw/mechanic/',file_name='details.csv'))
                ),
            target=Aws(
                url='console.aws.amazon.com',
                region='us-west-2',
                rds=Rds(database='client1-reference', schema='oem', tablename='employee')
            )
        )
    )
)

client1 = Client(client_id=1, client_name='Indigo', domain=meta_data)
print(client1)
print(dir(client1.domain))
# form a json for class client
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 7
#       1 meta_data = Domain(
#       2     domain_id=1,
#       3     domain_name='employee',
#       4     app=App(
#       5         app_id=1,
#       6         app_name='mechanic',
# ----> 7         resources=Resources(
#       8             source=Aws(
#       9                 url='console.aws.amazon.com',
#      10                 region='us-east-1',
#      11                 s3=S3(bucket=Bucket(name='indigo',prefix='raw/mechanic/',file_name='details.csv'))
#      12                 ),
#      13             target=Aws(
#      14                 url='console.aws.amazon.com',
#      15                 region='us-west-2',
#      16                 rds=Rds(database='client1-reference', schema='oem', tablename='employee')
#      17             )
#      18         )
#      19     )
#      20 )
#      22 client1 = Client(client_id=1, client_name='Indigo', domain=meta_data)
#      23 print(client1)
#
# TypeError: Resources.__init__() got an unexpected keyword argument 'target'
